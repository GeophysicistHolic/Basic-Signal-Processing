# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator

lt = 128
dt = 1
t = np.arange(0, lt-1, dt)


cross_chirp = np.cos(2*np.pi*(10+(t/7))*(t/lt)) + np.cos(2*np.pi*((lt/2.8)-(t/6.0))*(t/lt))

H = np.fft.fft(cross_chirp)


f = np.fft.fftfreq(len(t))
f = np.fft.fftshift(f)


h = np.zeros(len(t), dtype='complex')

for i in range(len(h)):
        h[i] = H[i]

M = np.zeros((len(h), len(f)))

for i in range(1,len(f)):
    G = np.exp((-2*(np.pi**2)*(f**2))/((f[i])**2))
    for j in range(len(h)):
        c = h[126]
        if j < int(len(h)-1):
            h[j] = h[j+1]
        h[126] = c
    a = G*h
    a = np.fft.ifft(a)
    M[:][i] = abs(a)


fig0, axs0 = plt.subplots(2, 1, sharex=True, constrained_layout=True)

axs0[0].plot(t, cross_chirp)
axs0[0].set_title('Original Signal Cross Chirp')
axs0[0].set(xlabel='Time(ms)', ylabel='Amplitude')

pcm = axs0[1].pcolormesh(t, abs(f[:64]), M[:][:64])
axs0[1].set_title('Gamma : 1, m : 1')
axs0[1].set(xlabel='Time(ms)', ylabel='Frekuensi (Hz)')

fig0.colorbar(pcm, ax=axs0[1], orientation='horizontal')
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_12684/785023366.py:28: RuntimeWarning: divide by zero encountered in true_divide
#   G = np.exp((-2*(np.pi**2)*(f**2))/((f[i])**2))
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_12684/785023366.py:28: RuntimeWarning: invalid value encountered in true_divide
#   G = np.exp((-2*(np.pi**2)*(f**2))/((f[i])**2))
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_12684/785023366.py:42: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(t, abs(f[:64]), M[:][:64])

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator

lt = 128
dt = 1
t = np.arange(0, lt-1, dt)


cross_chirp = np.cos(2*np.pi*(10+(t/7))*(t/lt)) + np.cos(2*np.pi*((lt/2.8)-(t/6.0))*(t/lt))

H = np.fft.fft(cross_chirp)


f = np.fft.fftfreq(len(t))
f = np.fft.fftshift(f)


h = np.zeros(len(t), dtype='complex')

for i in range(len(h)):
        h[i] = H[i]

M1 = np.zeros((len(h), len(f)))

for i in range(1,len(f)):
    gamma = 0.3
    m = 0.5
    G = np.exp((-2*(np.pi**2)*(abs(f)**2))/((gamma**2)*((abs(f[i]))**(2*m))))
    for j in range(len(h)):
        c = h[126]
        if j < int(len(h)-1):
            h[j] = h[j+1]
        h[126] = c
    a = G*h
    a = np.fft.ifft(a)
    M1[:][i] = abs(a)



fig1, axs1 = plt.subplots(2, 1, sharex=True, constrained_layout=True)

axs1[0].plot(t, cross_chirp)
axs1[0].set_title('Original Signal Cross Chirp')
axs1[0].set(xlabel='Time(ms)', ylabel='Amplitude')

pcm_1 = axs1[1].pcolormesh(t, abs(f[:64]), M1[:][:64])
axs1[1].set_title('Gamma : 0.5, m : 0.5')
axs1[1].set(xlabel='Time(ms)', ylabel='Frekuensi (Hz)')

fig1.colorbar(pcm_1, ax=axs1[1], orientation='horizontal')
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_12684/608634290.py:30: RuntimeWarning: divide by zero encountered in true_divide
#   G = np.exp((-2*(np.pi**2)*(abs(f)**2))/((gamma**2)*((abs(f[i]))**(2*m))))
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_12684/608634290.py:30: RuntimeWarning: invalid value encountered in true_divide
#   G = np.exp((-2*(np.pi**2)*(abs(f)**2))/((gamma**2)*((abs(f[i]))**(2*m))))
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_12684/608634290.py:44: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(t, abs(f[:64]), M1[:][:64])

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator

lt = 128
dt = 1
t = np.arange(0, lt-1, dt)


cross_chirp = np.cos(2*np.pi*(10+(t/7))*(t/lt)) + np.cos(2*np.pi*((lt/2.8)-(t/6.0))*(t/lt))

H = np.fft.fft(cross_chirp)


f = np.fft.fftfreq(len(t))
f = np.fft.fftshift(f)


h = np.zeros(len(t), dtype='complex_')

for i in range(len(h)):
        h[i] = H[i]

M2 = np.zeros((len(h), len(f)))

for i in range(1,len(f)):
    gamma = 0.4
    m = 0.2
    G = np.exp((-2*(np.pi**2)*(abs(f)**2))/((gamma**2)*((abs(f[i]))**(2*m))))
    for j in range(len(h)):
        c = h[126]
        if j < int(len(h)-1):
            h[j] = h[j+1]
        h[126] = c
    a = G*h
    a = np.fft.ifft(a)
    M2[:][i] = abs(a)


fig2, axs2 = plt.subplots(2, 1, sharex=True, constrained_layout=True)

axs2[0].plot(t, cross_chirp)
axs2[0].set_title('Original Signal Cross Chirp')
axs2[0].set(xlabel='Time(ms)', ylabel='Amplitude')

pcm_2 = axs2[1].pcolormesh(t, abs(f[:64]), M2[:][:64])
axs2[1].set_title('Gamma : 0.4, m : 0.2')
axs2[1].set(xlabel='Time(ms)', ylabel='Frekuensi (Hz)')

fig2.colorbar(pcm_2, ax=axs2[1], orientation='horizontal')
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_12684/3431217230.py:30: RuntimeWarning: divide by zero encountered in true_divide
#   G = np.exp((-2*(np.pi**2)*(abs(f)**2))/((gamma**2)*((abs(f[i]))**(2*m))))
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_12684/3431217230.py:30: RuntimeWarning: invalid value encountered in true_divide
#   G = np.exp((-2*(np.pi**2)*(abs(f)**2))/((gamma**2)*((abs(f[i]))**(2*m))))
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_12684/3431217230.py:44: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(t, abs(f[:64]), M2[:][:64])

# %%
fig, axs = plt.subplots(2, 2, constrained_layout=True)
axs[0,0].plot(t, cross_chirp)
axs[0, 0].set_title('Original Signal Cross Chirp')
axs[0,0].set(xlabel='Time(ms)', ylabel='Amplitude')

pcm2 = axs[0, 1].pcolormesh(t, abs(f[:64]), M[:][:64])
axs[0, 1].set_title('Gamma : 1, m : 1')
axs[0, 1].set(xlabel='Time(ms)', ylabel='Frekuensi (Hz)')
fig.colorbar(pcm2, ax=axs[0, 1], orientation='horizontal')

pcm3 = axs[1, 0].pcolormesh(t, abs(f[:64]), M1[:][:64])
axs[1, 0].set_title('Gamma : 0.5, m : 0.5')
axs[1, 0].set(xlabel='Time(ms)', ylabel='Frekuensi (Hz)')
fig.colorbar(pcm3, ax=axs[1,0], orientation='horizontal')

pcm4 = axs[1,1].pcolormesh(t, abs(f[:64]), M2[:][:64])
axs[1, 1].set_title('Gamma : 0.4, m : 0.2')
axs[1, 1].set(xlabel='Time(ms)', ylabel='Frekuensi (Hz)')
fig.colorbar(pcm4, ax=axs[1,1], orientation='horizontal')
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_12684/3845175594.py:5: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   axs[0,1].pcolormesh(t, abs(f[:64]), M[:][:64])
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_12684/3845175594.py:8: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   axs[1,0].pcolormesh(t, abs(f[:64]), M1[:][:64])
# ...
